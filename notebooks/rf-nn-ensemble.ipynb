# %% [markdown]
# # Intro

# %% [markdown]
# Some experiments to get a good score for the [Identify Age-Related Conditions][0] kaggle competition using decision tree models.
#
# Start by importing commonly used modules that make it convenient to work with the fastai library. Some will be patched to make them work in non-standard ways but improve interactivity.
#
# [0]: https://www.kaggle.com/competitions/icr-identify-age-related-conditions

# %%
from fastai.imports import *
from fastai.tabular.all import *

# %% [markdown]
# # Data Inspection
#
# Get the dataset appropriately whether we're in kaggle or not. If in kaggle, it is assumed the competition dataset has been connected to the notebook.

# %%
import os
competition_name = "icr-identify-age-related-conditions"

is_kaggle = os.environ.get('KAGGLE_KERNEL_RUN_TYPE', '')
if is_kaggle:
    path = Path(f"/kaggle/input/{competition_name}")
else:
    import zipfile, kaggle
    path = Path.home() / '.kaggle' / 'input' / competition_name
    kaggle.api.competition_download_cli(competition_name, path=path.parent)
    zipfile.ZipFile(f'{path}.zip').extractall(path)
# Out:
# icr-identify-age-related-conditions.zip: Skipping, found more recently modified local copy (use --force to force download)

# %% [markdown]
# Load the datasets. It's a small dataset so we can set the `low_memory` pandas flag to `False`.

# %%
path.ls()
# Out:
# (#4) [Path('/home/krm/.kaggle/input/icr-identify-age-related-conditions/test.csv'),Path('/home/krm/.kaggle/input/icr-identify-age-related-conditions/greeks.csv'),Path('/home/krm/.kaggle/input/icr-identify-age-related-conditions/train.csv'),Path('/home/krm/.kaggle/input/icr-identify-age-related-conditions/sample_submission.csv')]

# %%
df_train = pd.read_csv(f'{path}/train.csv', low_memory=False)
df_test = pd.read_csv(f'{path}/test.csv', low_memory=False)
df_train.head()
# Out:
#              Id        AB          AF          AH         AM        AR  \
# 0  000ff2bfdfe9  0.209377  3109.03329   85.200147  22.394407  8.138688
# 1  007255e47698  0.145282   978.76416   85.200147  36.968889  8.138688
# 2  013f2bd269f5  0.470030  2635.10654   85.200147  32.360553  8.138688
# 3  043ac50845d5  0.252107  3819.65177  120.201618  77.112203  8.138688
# 4  044fb8a146ec  0.380297  3733.04844   85.200147  14.103738  8.138688
#
#          AX        AY         AZ          BC  ...        FL        FR  \
# 0  0.699861  0.025578   9.812214    5.555634  ...  7.298162   1.73855
# 1  3.632190  0.025578  13.517790    1.229900  ...  0.173229   0.49706
# 2  6.732840  0.025578  12.824570    1.229900  ...  7.709560   0.97556
# 3  3.685344  0.025578  11.053708    1.229900  ...  6.122162   0.49706
# 4  3.942255  0.054810   3.396778  102.151980  ...  8.153058  48.50134
#
#          FS         GB          GE            GF         GH         GI  \
# ...

# %%
df_train.columns
# Out:
# Index(['Id', 'AB', 'AF', 'AH', 'AM', 'AR', 'AX', 'AY', 'AZ', 'BC', 'BD ', 'BN',
#        'BP', 'BQ', 'BR', 'BZ', 'CB', 'CC', 'CD ', 'CF', 'CH', 'CL', 'CR', 'CS',
#        'CU', 'CW ', 'DA', 'DE', 'DF', 'DH', 'DI', 'DL', 'DN', 'DU', 'DV', 'DY',
#        'EB', 'EE', 'EG', 'EH', 'EJ', 'EL', 'EP', 'EU', 'FC', 'FD ', 'FE', 'FI',
#        'FL', 'FR', 'FS', 'GB', 'GE', 'GF', 'GH', 'GI', 'GL', 'Class'],
#       dtype='object')

# %% [markdown]
# We can now examine the data.

# %%
df_train.describe()
# Out:
#                AB            AF           AH          AM          AR  \
# count  617.000000    617.000000   617.000000  617.000000  617.000000
# mean     0.477149   3502.013221   118.624513   38.968552   10.128242
# std      0.468388   2300.322717   127.838950   69.728226   10.518877
# min      0.081187    192.593280    85.200147    3.177522    8.138688
# 25%      0.252107   2197.345480    85.200147   12.270314    8.138688
# 50%      0.354659   3120.318960    85.200147   20.533110    8.138688
# 75%      0.559763   4361.637390   113.739540   39.139886    8.138688
# max      6.161666  28688.187660  1910.123198  630.518230  178.943634
#
#                AX          AY          AZ           BC           BD   ...  \
# count  617.000000  617.000000  617.000000   617.000000    617.000000  ...
# mean     5.545576    0.060320   10.566447     8.053012   5350.388655  ...
# std      2.551696    0.416817    4.350645    65.166943   3021.326641  ...
# ...

# %% [markdown]
# We see that the mean of the dependant column `Class` is much closer to zero than one. This means that the observations with a positive diagnosis are smaller in proportion in the training data. We confirm this by plotting a pie chart for column `Class`.

# %%
# %matplotlib inline

df_train.Class.value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# We also check for null values

# %%
df_train.isna().sum()
# Out:
# Id        0
# AB        0
# AF        0
# AH        0
# AM        0
# AR        0
# AX        0
# AY        0
# AZ        0
# BC        0
# BD        0
# BN        0
# BP        0
# BQ       60
# BR        0
# BZ        0
# CB        2
# CC        3
# CD        0
# CF        0
# CH        0
# CL        0
# CR        0
# CS        0
# CU        0
# CW        0
# DA        0
# DE        0
# DF        0
# DH        0
# DI        0
# DL        0
# DN        0
# DU        1
# DV        0
# DY        0
# EB        0
# EE        0
# EG        0
# EH        0
# EJ        0
# EL       60
# EP        0
# EU        0
# FC        1
# FD        0
# FE        0
# FI        0
# FL        1
# FR        0
# FS        2
# GB        0
# GE        0
# GF        0
# GH        0
# GI        0
# GL        1
# Class     0
# dtype: int64

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 617 entries, 0 to 616
# Data columns (total 58 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Id      617 non-null    object
#  1   AB      617 non-null    float64
#  2   AF      617 non-null    float64
#  3   AH      617 non-null    float64
#  4   AM      617 non-null    float64
#  5   AR      617 non-null    float64
#  6   AX      617 non-null    float64
#  7   AY      617 non-null    float64
#  8   AZ      617 non-null    float64
#  9   BC      617 non-null    float64
#  10  BD      617 non-null    float64
#  11  BN      617 non-null    float64
#  12  BP      617 non-null    float64
#  13  BQ      557 non-null    float64
#  14  BR      617 non-null    float64
#  15  BZ      617 non-null    float64
#  16  CB      615 non-null    float64
#  17  CC      614 non-null    float64
#  18  CD      617 non-null    float64
#  19  CF      617 non-null    float64
# ...

# %% [markdown]
#  # Data Processing
#
# We'll do some simple processing. We'll replace null values with the mode of their columns, and replace the categorical columns `EJ` and `Id` with numeric codes representing their levels.

# %%
modes = df_train.mode().iloc[0]

def process_data(df):
    df.fillna(modes, inplace=True)
    df["EJ"] = pd.Categorical(df.EJ).codes
    df["Id"] = pd.Categorical(df.Id).codes

    
process_data(df_train)
process_data(df_test)

# %% [markdown]
# Though the dataset is small we'll do a simple split on the dataframe for model training and validation datasets just to get some initial metrics.

# %%
from sklearn.model_selection import train_test_split

train_xy, valid_xy = train_test_split(df_train, test_size=0.25)
train_xy.shape, valid_xy.shape
# Out:
# ((462, 58), (155, 58))

# %% [markdown]
# Next, split each of our model training and validation sets to X and y values

# %%
ycol = "Class"
xcols = [col for col in train_xy.columns if not col == ycol]

def x_y(df):
    return df[xcols], df[ycol]

xs, y = x_y(train_xy)
valid_xs, valid_y = x_y(valid_xy)

# %% [markdown]
# # Modelling

# %% [markdown]
# We can then create a simple decision tree.

# %%
from sklearn.tree import DecisionTreeClassifier, export_graphviz

tree = DecisionTreeClassifier(max_leaf_nodes=4)
tree.fit(xs, y)
# Out:
# DecisionTreeClassifier(max_leaf_nodes=4)

# %%
import graphviz

def draw_tree(tree, df, size=10, ratio=0.6, precision=2, **kwargs):
    dot_format = export_graphviz(tree, out_file=None, feature_names=xs.columns, filled=True, rounded=True,
                                special_characters=True, rotate=False, precision=precision, **kwargs)
    return graphviz.Source(re.sub('Tree {', f'Tree {{ size={size}; ratio={ratio}', dot_format))

# %%
draw_tree(tree, xs)

# %% [markdown]
# The competition uses the balanced log loss metric which is explained more [here][0]. For our we'll use the simple implementation.
#
# [0]: https://www.kaggle.com/competitions/icr-identify-age-related-conditions/discussion/422442

# %%
from sklearn.metrics import log_loss
def balanced_log_loss(y_true, y_pred):
    nc = np.bincount(y_true)
    return log_loss(y_true, y_pred, sample_weight = 1/nc[y_true], eps=1e-15)

def m_log_loss(model, xs, y): return balanced_log_loss(np.array(y), np.array(model.predict(xs)))

# %%
m_log_loss(tree, xs, y), m_log_loss(tree, valid_xs, valid_y)
# Out:
# (5.791747090853977, 5.556610541693519)

# %% [markdown]
# The important metric is the one on the validation set, but including the training one as well just to see how it fits the training data.
#
# The log loss is ~ 6.2 with the small tree. We can try a larger tree as well without any restrictions.

# %%
tree = DecisionTreeClassifier()
tree.fit(xs, y)

m_log_loss(tree, xs, y), m_log_loss(tree, valid_xs, valid_y)
# Out:
# (9.992007221626415e-16, 11.85275414905896)

# %%
draw_tree(tree, xs, ratio=0.6, size=50)

# %% [markdown]
# Seems to overfit.
#
# Or maybe specify min samples per node to reduce overfitting

# %%
tree = DecisionTreeClassifier(min_samples_leaf=25)
tree.fit(xs, y)

m_log_loss(tree, xs, y), m_log_loss(tree, valid_xs, valid_y)
# Out:
# (7.865007483239075, 12.122594586499122)

# %%
draw_tree(tree, xs, ratio=1)

# %% [markdown]
# We can try Random Forests as well to see if there's any improvement.

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()
rf.fit(xs, y)

m_log_loss(rf, xs, y), m_log_loss(rf, valid_xs, valid_y)
# Out:
# (9.992007221626415e-16, 8.584731051029772)

# %% [markdown]
# Random forest with custom parameters.

# %%
def random_forest(xs, y, n_estimators=300, max_samples=0.75, max_features="sqrt", min_samples_leaf=5, **kwargs):
    return RandomForestClassifier(
        n_estimators=n_estimators,
        max_samples=max_samples,
        max_features=max_features,
        min_samples_leaf=min_samples_leaf,
        **kwargs
    ).fit(xs, y)

rf = random_forest(xs, y)

# %%
m_log_loss(rf, xs, y), m_log_loss(rf, valid_xs, valid_y)
# Out:
# (2.9848325279552452, 10.23371152441798)

# %% [markdown]
# Let's see how the OOB predictions compare.

# %%
rf = random_forest(xs, y, oob_score=True)

oob_preds = rf.oob_decision_function_
oob_preds_class_1 = oob_preds[:,1]
balanced_log_loss(y, oob_preds_class_1)
# Out:
# 0.5162285395569743

# %% [markdown]
# The OOB predictions look quite good. Since our dataset is quite small, we can inspect the OOB metrics for the complete training dataset.

# %%
full_xs, full_y = x_y(df_train)
full_xs.shape, full_y.shape
# Out:
# ((617, 57), (617,))

# %%
rf = random_forest(full_xs, full_y, oob_score=True)

oob_preds = rf.oob_decision_function_
oob_preds_class_1 = oob_preds[:,1]

balanced_log_loss(full_y, oob_preds_class_1)
# Out:
# 0.4892739002269641

# %% [markdown]
# # Submission
#
# Looks slightly better with the full training dataset. We can submit to kaggle and see whether there are any improvements over previous submissions.

# %%
submit=False  # Skip if false
if is_kaggle and submit:
    test_probs = rf.predict_proba(df_test[xcols])
    df_submission = pd.read_csv(f"{path}/sample_submission.csv")
    df_submission[["class_0", "class_1"]] = test_probs
    df_submission.to_csv("submission.csv", index=False)

# %% [markdown]
# This had the best score yet (0.37) on the public leaderboard.
#
# # Model Interpretation
#
# With our local train/validate split, there's quite a difference between the logloss metric on the validation set at ~9.8 and on the OOB predictions at ~0.5.
#
# We can try see whether we something apart from the generalization error accounts for this.
#
# # Variance for prediction confidence
#
# For the random forest, a prediction for each row is the average predition over all trees. To see which rows we can be more confident about the prediction, we can get each tree's individual prediction and calculate the std deviation. The lower it is, the more we can be confident about the prediction.

# %%
rf = random_forest(xs, y)

preds = np.stack([t.predict(valid_xs) for t in rf.estimators_])
preds.shape
# Out:
# /home/krm/projects/icr-competition/.env/lib/python3.8/site-packages/sklearn/base.py:432: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /home/krm/projects/icr-competition/.env/lib/python3.8/site-packages/sklearn/base.py:432: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /home/krm/projects/icr-competition/.env/lib/python3.8/site-packages/sklearn/base.py:432: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /home/krm/projects/icr-competition/.env/lib/python3.8/site-packages/sklearn/base.py:432: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# ...

# %%
preds_std = preds.std(axis=0)
preds_std.min(), preds_std.max()
# Out:
# (0.0, 0.49998888876542924)

# %% [markdown]
# The std deviation ranges from 0 to ~0.5. To get a row who's prediction we can be confident of, i.e. with a std deviation of 0, we can do like so:

# %%
idx = preds_std.argmin()
valid_xs.iloc[idx,:]
# Out:
# Id       208.000000
# AB         0.260653
# AF      1642.843620
# AH        85.200147
# AM         8.433131
# AR         8.138688
# AX         3.401856
# AY         0.025578
# AZ        15.049176
# BC         1.229900
# BD      6678.137880
# BN        20.832900
# BP       188.932230
# BQ        10.323615
# BR        51.216883
# BZ       257.432377
# CB        38.298897
# CC         0.642738
# CD        80.754608
# CF        16.527835
# CH         0.027860
# CL         1.050225
# CR         0.926850
# CS        23.708113
# CU         2.289555
# CW        39.965168
# DA        66.646760
# DE       541.810645
# DF         0.238680
# DH         0.472809
# DI       177.670350
# DL        94.197960
# DN        15.258464
# DU         0.005518
# DV         1.743070
# DY        31.668600
# EB         6.742872
# EE         2.737049
# EG      1047.265500
# EH         0.003042
# EJ         0.000000
# EL       109.125159
# EP        78.526968
# EU        53.546736
# FC        30.564912
# ...

# %% [markdown]
# We can also determine the feature importance by reading the `feature_importances_` model attribute. For each split, while training, the model keeps track of how it improves the model by how it affects the gini score. These are then aggregated for each column. Because of the small size of our dataset, we'll use the whole of it.

# %%
def rf_feature_importance(model, df):
    return pd.DataFrame({'cols': df.columns, 'importance': model.feature_importances_}).sort_values('importance', ascending=False)

rf = random_forest(full_xs, full_y)

feature_importance = rf_feature_importance(rf, full_xs)
feature_importance[:10]
# Out:
#    cols  importance
# 33   DU    0.135409
# 48   FL    0.058899
# 22   CR    0.057349
# 30   DI    0.053247
# 56   GL    0.049753
# 26   DA    0.044866
# 45  FD     0.036280
# 9    BC    0.035823
# 1    AB    0.033683
# 39   EH    0.032726

# %% [markdown]
# We can plot this:

# %%
def plot_feature_importance(feature_importance):
    feature_importance.plot('cols', 'importance', 'barh', figsize=(12, 10), legend=False)
    
plot_feature_importance(feature_importance)

# %% [markdown]
# At this point we could remove the low importance features. Let's first establish a baseline score with all the columns:

# %%
def get_model_score(xs, y):
    rf = random_forest(xs, y, oob_score=True)
    rf.fit(xs, y)
    
    oob_preds = rf.oob_decision_function_
    oob_preds_class_1 = oob_preds[:,1]
    return balanced_log_loss(y, oob_preds_class_1)

get_model_score(full_xs, full_y)
# Out:
# 0.48144181333040936

# %% [markdown]
# Then we can remove some of the low importance columns and see the impact on the score. We know that `Id` should not have much of a predictive value, so any columns with similar importance can be removed.

# %%
feature_importance_d = dict((zip(feature_importance.cols, feature_importance.importance)))

important_cols = [col for col in full_xs.columns if feature_importance_d[col] > 0.01]

full_xs_imp = full_xs[important_cols]

get_model_score(full_xs_imp, full_y)
# Out:
# 0.46324807985011013

# %% [markdown]
# Several runs of this seems to show a better score locally.
#
# # Submission
# We can submit this to kaggle and see how it scores on the leaderboard.

# %%
submit=False
if is_kaggle and submit:
    rf = random_forest(full_xs_imp, full_y)
    test_probs = rf.predict_proba(df_test[important_cols])
    df_submission = pd.read_csv(f"{path}/sample_submission.csv")
    df_submission[["class_0", "class_1"]] = test_probs
    df_submission.to_csv("submission.csv", index=False)

# %% [markdown]
# This achieved the best yet performance of 0.35. What if we just used the top 10 most important columns?

# %%
top_cols = list(feature_importance[:10]['cols'])
get_model_score(full_xs[top_cols], full_y)
# Out:
# 0.47593931916571774

# %% [markdown]
#  It seems slightly worse than our best one yet. We can submit it just to see what score it lands on the leaderboard.

# %%
submit=False
if is_kaggle and submit:
    rf = random_forest(full_xs[top_cols], full_y)
    test_probs = rf.predict_proba(df_test[top_cols])
    df_submission = pd.read_csv(f"{path}/sample_submission.csv")
    df_submission[["class_0", "class_1"]] = test_probs
    df_submission.to_csv("submission.csv", index=False)

# %% [markdown]
# This achieved a score of 0.4, so probably not better than just removing the low importance features by score

# %% [markdown]
# # Redundant Features
#
# We can inspect the correlation between features. The similarity is calculated by replacing each value with it's rank in the column (i.e. first, second, third etc) and calculating the correlation of that.

# %%
from scipy.cluster import hierarchy as hc

def cluster_columns(df, figsize=(10,6), font_size=12):
    corr = np.round(scipy.stats.spearmanr(df).correlation, 4)
    corr_condensed = hc.distance.squareform(1-corr)
    z = hc.linkage(corr_condensed, method='average')
    fig = plt.figure(figsize=figsize)
    hc.dendrogram(z, labels=df.columns, orientation='left', leaf_font_size=font_size)
    plt.show()

# %%
cluster_columns(full_xs_imp, figsize=(10,18))

# %% [markdown]
# The features that merge earliest from the right are the most similar. As we see here, FD and EH are most similar, followed by FL and DU.
#
# We can try see how dropping any of these affects the model's performance over the complete dataset.

# %% [markdown]
# We'll try remove each of the similar ones one by one.

# %%
similar_columns = ["FD ", "EH", "FL", "DU"]

{c: get_model_score(full_xs_imp.drop(c, axis=1), full_y) for c in similar_columns}
# Out:
# {'FD ': 0.4713333143619772,
#  'EH': 0.4657129458090591,
#  'FL': 0.47488235789008015,
#  'DU': 0.5112638966189734}

# %% [markdown]
# Removing DU seems to have a noticeable performance penalty. Makes sense given that DU is the most important feature.

# %% [markdown]
# # Partial Dependence
#
# The most important features are DU, and FL. We can plot their distribution.

# %%
import seaborn as sns

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(11, 5))
sns.kdeplot(data=full_xs, x="DU", ax=ax1)
sns.kdeplot(data=full_xs, x="FL", ax=ax2)
# Out:
# <Axes: xlabel='FL', ylabel='Density'>

# %% [markdown]
# They look quite similar in distribution.

# %% [markdown]
# We can now investigate how, all things being equal, changing the values of these columns affect the final prediction. It works by freezing the values of all other columns, changing the value of the selected column from smallest to largest in the dataset across all rows, making the predictions and getting the average prediction. This average is plotted against the column's values.

# %%
from sklearn.inspection import PartialDependenceDisplay
rf = random_forest(xs, y)

fig, ax = plt.subplots(figsize=(12, 4))
PartialDependenceDisplay.from_estimator(rf, valid_xs, ["DU", "FL"], ax=ax)

# %% [markdown]
# Looks like for both, for a very narrow range of values, there's a positive correlation with the score. Going by the distribution, we can filter out rows where DU > 25 and FL is > 30.

# %%
fig, ax = plt.subplots(figsize=(12, 4))

xs_filtered = valid_xs[valid_xs.DU <= 25]
xs_filtered = xs_filtered[xs_filtered.FL <= 30]

PartialDependenceDisplay.from_estimator(rf, xs_filtered, ["DU", "FL"], ax=ax)

# %% [markdown]
# In the previous section we also saw that FD and EH have a high similarity. we can likewise plot their distribution:

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(11, 5))
sns.kdeplot(data=full_xs, x="FD ", ax=ax1)
sns.kdeplot(data=full_xs, x="EH", ax=ax2)
# Out:
# <Axes: xlabel='EH', ylabel='Density'>

# %% [markdown]
# We can also see they relate to the class prediction:

# %%
rf = random_forest(xs, y)

fig, ax = plt.subplots(figsize=(12, 4))
PartialDependenceDisplay.from_estimator(rf, valid_xs, ["FD ", "EH"], ax=ax)

# %% [markdown]
# # Neural Network
#
# We can compare the performance of a neural network with that of the random forest. However, we'll leverage the work we already did to identify important columns.

# %%
df_nn = df_train[important_cols + [ycol]]
df_nn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 617 entries, 0 to 616
# Data columns (total 26 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AB      617 non-null    float64
#  1   AF      617 non-null    float64
#  2   AM      617 non-null    float64
#  3   BC      617 non-null    float64
#  4   BN      617 non-null    float64
#  5   BR      617 non-null    float64
#  6   CC      617 non-null    float64
#  7   CD      617 non-null    float64
#  8   CR      617 non-null    float64
#  9   DA      617 non-null    float64
#  10  DE      617 non-null    float64
#  11  DF      617 non-null    float64
#  12  DH      617 non-null    float64
#  13  DI      617 non-null    float64
#  14  DL      617 non-null    float64
#  15  DU      617 non-null    float64
#  16  EB      617 non-null    float64
#  17  EE      617 non-null    float64
#  18  EH      617 non-null    float64
#  19  FD      617 non-null    float64
# ...

# %% [markdown]
# We use TabularPandas to create a dataset for the neural network. For the neural network, we'll need to normalize the values in the dataset. We also specify a train/validation split. We specify `y_block=CategoryBlock()` to create a classifier, rather than a regression model.

# %%
train_valid_splits = (list(xs.index), list(valid_xs.index))

tabular_ds = TabularPandas(
    df=df_nn,
    procs=[Normalize],
    cont_names=important_cols,
    y_names=ycol,
    splits=train_valid_splits,
    y_block=CategoryBlock
)

# %% [markdown]
# Next, we create a tabular learner, i.e. a neural network to learn from tabular data.
#
# We first get a dataloaders object from the tabular dataset.

# %%
dataloaders = tabular_ds.dataloaders()  # default batch size 16

# %%
dataloaders.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>AB</th>
#       <th>AF</th>
#       <th>AM</th>
#       <th>BC</th>
#       <th>BN</th>
#       <th>BR</th>
#       <th>CC</th>
#       <th>CD</th>
#       <th>CR</th>
#       <th>DA</th>
#       <th>DE</th>
#       <th>DF</th>
#       <th>DH</th>
#       <th>DI</th>
#       <th>DL</th>
#       <th>DU</th>
#       <th>EB</th>
#       <th>EE</th>
#       <th>EH</th>
#       <th>FD</th>
#       <th>FE</th>
#       <th>FI</th>
#       <th>FL</th>
#       <th>FR</th>
#       <th>GL</th>
#       <th>Class</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.734956</td>
#       <td>6296.695801</td>
#       <td>61.013996</td>
#       <td>1.229900</td>
#       <td>27.541800</td>
#       <td>1583.658447</td>
#       <td>0.670100</td>
#       <td>52.269302</td>
#       <td>1.180650</td>
#       <td>97.830322</td>
#       <td>238.079666</td>
# ...

# %% [markdown]
# Then we create the learner. By default it will create a neural network with two hidden layers of 200 and 100 activations. This should be sufficient with the small dataset.

# %%
learner = tabular_learner(dataloaders)

# %%
learner.lr_find()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# SuggestedLRs(valley=0.002511886414140463)

# %% [markdown]
# As suggested, we can use a learning rate of 1e-2. We can then train for a few epochs:

# %%
learner.fit_one_cycle(n_epoch=8, lr_max=1e-2)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.669478</td>
#       <td>0.596851</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
# ...

# %% [markdown]
# Next we get the preditions on the validation set, together with the targets.

# %%
preds, targets = learner.get_preds()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %% [markdown]
# We can now get the logloss score

# %%
balanced_log_loss(targets.flatten(), preds[:,1])
# Out:
# 0.7614503952191121

# %% [markdown]
# So looks like the performance is slightly worse than the random forest.

# %% [markdown]
# # Ensembling
#
# We can combine average the predictions of a random forest with the neural network model.

# %%
rf = random_forest(xs[important_cols], y)

# %%
rf_preds = rf.predict(valid_xs[important_cols])
nn_preds = preds[:,1].numpy()

# %%
ensemble_preds = (rf_preds + nn_preds) / 2

# %% [markdown]
# We then score the ensemble

# %%
balanced_log_loss(valid_y, ensemble_preds)
# Out:
# 0.8521499901693865

# %% [markdown]
# This seems to perform worse locally than the random forest. Nevertheless, we can submit it to the leaderboard and see how it ranks.

# %% [markdown]
# # Submission

# %% [markdown]
# We repeat the data prep steps for the neural network model on the test set.

# %%
submit=True
if is_kaggle and submit:
    # get nn and rf preds
    test_dl = learner.dls.test_dl(df_test[important_cols])
    nn_test_probs, _ = learner.get_preds(dl=test_dl)
    rf_test_probs = rf.predict_proba(df_test[important_cols])
    # get the average
    ensemble_preds = (nn_test_probs.numpy() + rf_test_probs) / 2
    # create submission
    df_submission = pd.read_csv(f"{path}/sample_submission.csv")
    df_submission[["class_0", "class_1"]] = ensemble_preds
    df_submission.to_csv("submission.csv", index=False)

# %% [markdown]
# This ensemble scored 0.34, which is the best yet of our submissions. Next we shall look at better ways of doing training and validation e.g. cross-validation.
